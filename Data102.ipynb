# %% [markdown]
# <a href="https://colab.research.google.com/github/wilaipa/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# นำเข้าไฟล์
import os
# นำเข้าไฟล์แพนด้า เปลี่ยนชื่อเป็น pd เพื่อจัดการไฟล์ที่เป็นตาราง กราฟ
import pandas as pd
# สร้างตัวแปรเก็บโฟลเดอร์ที่เราต้องการ
base_path = '/content/drive/My Drive/DWDM_material'

data = pd.read_csv(os.path.join(base_path,'test.csv'))
# แสดงหัวข้อตาราง
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['y'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fea2d0ce240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fea2d0cec50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fea2d0da710>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fea2d0da390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fea2d0ce550>,
#   <matplotlib.lines.Line2D at 0x7fea2d0ce8d0>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fea2d0a7f60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fea2d0b19b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fea2d0be470>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fea2d0be0f0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fea2d0b12b0>,
#   <matplotlib.lines.Line2D at 0x7fea2d0b1630>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fea2d017048>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fea2d017a58>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fea2d021518>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fea2d021198>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fea2d017358>,
#   <matplotlib.lines.Line2D at 0x7fea2d0176d8>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %%
oput['fliers'][0]

# %% [markdown]
# # Scatterplot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#9467bd',marker="3")

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#9467bd',marker="3",alpha=0.4)
plt.scatter([44,42,50],[15,14,80],s=250,c='#9467bd',alpha=0.6)

# %% [markdown]
# HW4 วาดปีกกับนอ ให้ไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='#FFCCCC',marker="*")
plt.scatter([38,36,34,32,30,28,26,28,30,32,34,36,38,40,42,43,44,84,86,88,90,92,94,96,98,100,100,100,98,96,94,92,90,88,86,84,82,82,82,82,82,82],[83,85,87,89,91,93,95,94,94,94,94,94,94,94,94,94,94,35,38,41,44,47,50,53,56,59,63,68,72,75,74,71,68,65,61,58,54,50,46,42,38,35],s=70,alpha=0.6,c='#FF9999',marker=",")
plt.scatter([50],[80],s=250,alpha=0.6,c='#E75F49')

# %%
plt.plot(data['x'],data['y'])

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k')

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10),c='c')

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.2,0.1,0.4,0.5]])

# %%
color_list = [] 
for i in range(len(data['x'])) :
     color_list.append([0.2,0.1,i/255,0.5]) 
color_list
# Out:
# [[0.2, 0.1, 0.0, 0.5],
#  [0.2, 0.1, 0.00392156862745098, 0.5],
#  [0.2, 0.1, 0.00784313725490196, 0.5],
#  [0.2, 0.1, 0.011764705882352941, 0.5],
#  [0.2, 0.1, 0.01568627450980392, 0.5],
#  [0.2, 0.1, 0.0196078431372549, 0.5],
#  [0.2, 0.1, 0.023529411764705882, 0.5],
#  [0.2, 0.1, 0.027450980392156862, 0.5],
#  [0.2, 0.1, 0.03137254901960784, 0.5],
#  [0.2, 0.1, 0.03529411764705882, 0.5],
#  [0.2, 0.1, 0.0392156862745098, 0.5],
#  [0.2, 0.1, 0.043137254901960784, 0.5],
#  [0.2, 0.1, 0.047058823529411764, 0.5],
#  [0.2, 0.1, 0.050980392156862744, 0.5],
#  [0.2, 0.1, 0.054901960784313725, 0.5],
#  [0.2, 0.1, 0.058823529411764705, 0.5],
#  [0.2, 0.1, 0.06274509803921569, 0.5],
#  [0.2, 0.1, 0.06666666666666667, 0.5],
#  [0.2, 0.1, 0.07058823529411765, 0.5],
#  [0.2, 0.1, 0.07450980392156863, 0.5],
#  [0.2, 0.1, 0.0784313725490196, 0.5],
#  [0.2, 0.1, 0.08235294117647059, 0.5],
#  [0.2, 0.1, 0.08627450980392157, 0.5],
#  [0.2, 0.1, 0.09019607843137255, 0.5],
# ...

# %%
plt.scatter(data['x'],data['y'],s=250,c=color_list)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  
width = 0.35

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
# Out:
# <BarContainer object of 5 artists>

# %%
#เป็นการสร้างกราฟอีกแบบหนึ่งที่ยากขึ้นอีก
fig, ax = plt.subplots()  
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')
#เปลี่ยนชื่อแกนy
ax.set_ylabel('Scores') 
#ชื่อกราฟ
ax.set_title('Scores by group and gender')
#เปลี่ยนค่าของแกนxเป็นแกนตามที่เรากำหนด
ax.set_xticks(x)
ax.set_xticklabels(labels)
#บอกว่าสีแต่ละแท่งคืออะไร ข้อมูลเอามาจาก rects1 rects2
ax.legend()

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores') 
plt.title('Scores by group and gender')
plt.legend() ;

# %% [markdown]
# ## Histogram

# %%
x=[12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
